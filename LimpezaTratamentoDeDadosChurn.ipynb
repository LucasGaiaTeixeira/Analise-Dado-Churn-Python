# %%
import pandas as pd
import seaborn as srn
import statistics as est
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("churn.csv", sep=";", encoding="utf-8")

dados.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
dados.describe()
# Out:
#                 X0          X1          X4        X4.1            X6  \
# count   999.000000  999.000000  999.000000  999.000000  9.990000e+02
# mean    500.916917  648.621622   38.902903    5.069069  7.164928e+06
# std     288.662884   98.264219   11.401912    2.927691  6.311840e+06
# min       1.000000  376.000000  -20.000000    0.000000  0.000000e+00
# 25%     251.500000  580.000000   32.000000    2.000000  0.000000e+00
# 50%     501.000000  653.000000   37.000000    5.000000  8.958835e+06
# 75%     750.500000  721.000000   44.000000    8.000000  1.258684e+07
# max    1000.000000  850.000000  140.000000   10.000000  2.117743e+07
#
#                X7          X8         X9           X10         X11
# count  999.000000  999.000000  999.00000  9.920000e+02  999.000000
# mean     1.526527    0.702703    0.50951  3.528762e+07    0.203203
# std      0.574201    0.457297    0.50016  5.305800e+08    0.402584
# min      1.000000    0.000000    0.00000  9.677000e+03    0.000000
# ...

# %%
dados.shape
# Out:
# (999, 12)

# %%
dados.columns = ["Id","Score","Estado","Genero","Idade","Patrimonio","Saldo","Produtos","TemCartCredito",
                    "Ativo","Salario","Saiu"]

# %%
EstadoAgrupado = dados.groupby(["Estado"]).size()
EstadoAgrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
dados.head(20)
# Out:
#     Id  Score Estado     Genero  Idade  Patrimonio     Saldo  Produtos  \
# 0    1    619     RS   Feminino     42           2         0         1
# 1    2    608     SC   Feminino     41           1   8380786         1
# 2    3    502     RS   Feminino     42           8   1596608         3
# 3    4    699     RS   Feminino     39           1         0         2
# 4    5    850     SC   Feminino     43           2  12551082         1
# 5    6    645     SC  Masculino     44           8  11375578         2
# 6    7    822     RS          M     50           7         0         2
# 7    8    376     PR   Feminino     29           4  11504674         4
# 8    9    501     RS  Masculino     44           4  14205107         2
# 9   10    684     RS  Masculino     27           2  13460388         1
# 10  11    528     RS  Masculino     31           6  10201672         2
# 11  12    497     SC  Masculino     24           3         0         2
# ...

# %% [markdown]
# # Dados que precisam Ser agupados como categoricos ou booleanos

# %% [markdown]
# <h4>Estados</h4>

# %%
agrupadoEstado = dados.groupby(["Estado"]).size()
agrupadoEstado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
srn.boxplot(agrupadoEstado).set_title("Boxplot Estado")
srn.barplot(agrupadoEstado).set_title("Barplot Estado + boxplot Estado")
# Out:
# Text(0.5, 1.0, 'Barplot Estado + boxplot Estado')

# %% [markdown]
# <h4>Genero</h4>

# %%
agrupadoGenero = dados.groupby(["Genero"]).size()
agrupadoGenero
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
srn.barplot(agrupadoGenero).set_title("Barplot Genero")
# Out:
# Text(0.5, 1.0, 'Barplot Genero')

# %% [markdown]
# <h4>Saiu</h4>

# %%
agrupadosSaiu = dados.groupby(["Saiu"]).size()
agrupadosSaiu
# Out:
# Saiu
# 0    796
# 1    203
# dtype: int64

# %%
srn.barplot(agrupadosSaiu).set_title("Barplot Saiu")
# Out:
# Text(0.5, 1.0, 'Barplot Saiu')

# %% [markdown]
# <h4>Tem Cartão de Credito</h4>

# %%
agrupadosTemCartCredito = dados.groupby(["TemCartCredito"]).size()
agrupadosTemCartCredito
# Out:
# TemCartCredito
# 0    297
# 1    702
# dtype: int64

# %%
srn.barplot(agrupadosTemCartCredito).set_title("Barplot Tem Cartão de Crédito")
# Out:
# Text(0.5, 1.0, 'Barplot Tem Cartão de Crédito')

# %% [markdown]
# <h4>Ativo</h4>

# %%
agrupadosAtivo = dados.groupby(["Ativo"]).size()
agrupadosAtivo
# Out:
# Ativo
# 0    490
# 1    509
# dtype: int64

# %%
srn.barplot(agrupadosAtivo).set_title("Barplot Genero")
# Out:
# Text(0.5, 1.0, 'Barplot Genero')

# %% [markdown]
# # Dados que não precisam ser Agrupados: numericos

# %% [markdown]
# <h4>Patrimonio</h4>

# %%
dados["Patrimonio"].describe()
# Out:
# count    999.000000
# mean       5.069069
# std        2.927691
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000
# Name: Patrimonio, dtype: float64

# %%
srn.boxplot(dados["Patrimonio"]).set_title("Barplot Patrimonio")
# Out:
# Text(0.5, 1.0, 'Barplot Patrimonio')

# %% [markdown]
# <h4>Idade</h4>

# %%
dados["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dados["Idade"]).set_title("Boxplot Idade")
# Out:
# Text(0.5, 1.0, 'Boxplot Idade')

# %% [markdown]
# <h4>Saldo</h4>

# %%
dados.loc[dados["Saldo"] == 0,"Saldo"].count()
# Out:
# np.int64(350)

# %%
srn.boxplot(dados["Saldo"]).set_title("Boxplot Saldo")
# Out:
# Text(0.5, 1.0, 'Boxplot Saldo')

# %%
dados.isnull().sum()
# Out:
# Id                0
# Score             0
# Estado            0
# Genero            8
# Idade             0
# Patrimonio        0
# Saldo             0
# Produtos          0
# TemCartCredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %% [markdown]
# <h4>Salario</h4>

# %%
dados["Salario"].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: Salario, dtype: float64

# %%
srn.boxplot(dados["Salario"]).set_title("Boxplot Salário")
# Out:
# Text(0.5, 1.0, 'Boxplot Salário')

# %% [markdown]
# # Dados Corrigidos

# %% [markdown]
# # analise de "Churn" rotatividade de clientes
# * 1 : Ponto central varaivel mais importante Score tentendo a quantidade de compras que um cliente tem feito na empresa | variavel independente
# * 2 : Estados Apenas da Região sudeste
# * 3 : Clientes que não sairam muito maior do que os que sairam possivelmente indicando que estão satisfeitos com o negocio
# * 4 : Clientes concentrados em RS
# * 5 : Idade dos clientes bem medianas, mas alguns clientes acima da media de idades, mas bem poucos, podem ser antigos clientes, ou o negocio não tem o publico de pessoas idosas, mas entre 40 e 30 anos esta bem forte
# * 6 : Existem 350 contas de usuarios que estão com valor 0 em saldos 0 de 999 contas, possivelmente estariam testando o produto do negocio na empresa e não quiseram seguir em frente
# * 7 : Existem 702 clientes que possuem cartão de credito e 297 que não possue, dando a entender que existe uma alta confiabilidade desta empresa, que esse 20% possam nào querer estar com confiaça no negocio ou estão com algum tipo de receio
# * 8 : baixo qualificação do negocio, com 490 não ativos e 509 ativos, podendo ser falta de atrativos para os clientes
# * 9 : 4 contas com salarios anuais sendo muito altos, ou podendo ser um erro ou outra coisa
#
#
# # Correção de valores errados
# * Estados Contem Chaves de valores incorretas
# * Genero Contem chaves com falta de padronizaçao
# * Idade tem um valor de -20 anos e um de 140 anos de idade
#
#
# # Correção de dados faltantes
# * Existem valores faltantes nas tabelas:  Salario e Genero
